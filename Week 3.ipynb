# %%
from pyathena import connect
import pandas as pd

# %%
conn = connect(
    s3_staging_dir="s3://my-healthcare-bucket-bishal-2026/athena-staging/",
    region_name="eu-north-1" 
)

# %%
query = "SELECT * From insurance_curated LIMIT 5"

# %%
df=pd.read_sql(query,conn)
print(df.head())
# Out:
# /var/folders/bw/585kjh310_d1cprt77jb58xw0000gp/T/ipykernel_18747/1214911970.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(query,conn)
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /usr/local/lib/python3.10/site-packages/pandas/io/sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# File /usr/local/lib/python3.10/site-packages/pyathena/cursor.py:219, in Cursor.execute(self, operation, parameters, work_group, s3_staging_dir, cache_size, cache_expiration_time, result_reuse_enable, result_reuse_minutes, paramstyle, on_start_query_execution, **kwargs)
#     218 else:
# ...
